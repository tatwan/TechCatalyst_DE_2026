# %% [markdown]
# ### Instructions
#
# * **Kernel:** the shared repo-root `.venv` (same kernel as every Day 1 notebook).
# * **AI-Free Zone:** write the code yourself.
# * Download the Yellow Taxi data for January 2026 from the official TLC page (https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page), or directly from the TLC CDN. From your work folder:
#
# **Note** The data is made available to you in 'data/yellow_tripdata_2026-01.parquet'
#
# * This is about 64.2 MB and 3.7 million rows: your first realistically sized file in this course.
# * Use pandas to inspect the data and perform the transformations below. The expected outputs are shown after several cells so you can check yourself.
# * Finally, write the output as a partitioned parquet file.
#
# > **pandas 3 note:** the embedded outputs in this notebook were captured on an older pandas. Two harmless differences you may see today: text columns show dtype `str` instead of `object`, and `SettingWithCopyWarning` no longer exists (pandas 3 uses Copy-on-Write instead).

# %%
import pandas as pd
from pathlib import Path

# %%
# read the file you downloaded to yellow_tripdata_2024-04.parquet
import pandas as pd

DATA_PATH = #TODO
OUT_DIR = #TODO

# %%
# inspect few records
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2026-01-01 00:54:04   2026-01-01 00:59:37              1.0
# 1         1  2026-01-01 00:34:04   2026-01-01 00:39:47              0.0
# 2         1  2026-01-01 00:57:06   2026-01-01 01:05:59              0.0
# 3         2  2026-01-01 00:15:22   2026-01-01 00:58:10              4.0
# 4         2  2026-01-01 00:27:13   2026-01-01 00:40:43              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           239           238
# 1           0.90         1.0                  N           163           162
# 2           1.40         1.0                  N            43           237
# 3           5.58         1.0                  N           142           209
# 4           2.16         1.0                  N            88           144
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# inspect size
# Out:
# (3724889, 20)

# %%
# inspect the data
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3724889 entries, 0 to 3724888
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     str
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
# ...

# %%
# calculate Trip Duration in Minutes. Call it Trip_Duration. Check out how the results look like in below cells.


df[['Trip_Duration']].head()
# Out:
#    Trip_Duration
# 0            5.0
# 1            5.0
# 2            8.0
# 3           42.0
# 4           13.0

# %%
# Calculate Total Trip Charge to inclide: fare amount, extra, mta_tax, tolls amount, improvement surcharge, congestion surcharge, airport fee, and tip amount
# CAll it Total_Trip_Charge



df[['Total_Trip_Charge']].head()
# Out:
#    Total_Trip_Charge
# 0              15.86
# 1              16.15
# 2              21.45
# 3              54.81
# 4              22.35

# %%
# What is the most common passenger count?
# Out:
# passenger_count
# 1.0    2150994
# 2.0     334370
# 3.0      72864
# 4.0      49738
# 0.0      14787
# 5.0       9184
# 6.0       4887
# 8.0          4
# 7.0          2
# 9.0          1
# Name: count, dtype: int64

# %%
# Add Trip Date, Trip Month Name, Trip Day Name, and Trip Year
# call them Trip_Date, Trip_Month, Trip_Day, and Trip_Year

# %%
# this is how the data looks like now
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2026-01-01 00:54:04   2026-01-01 00:59:37              1.0
# 1         1  2026-01-01 00:34:04   2026-01-01 00:39:47              0.0
# 2         1  2026-01-01 00:57:06   2026-01-01 01:05:59              0.0
# 3         2  2026-01-01 00:15:22   2026-01-01 00:58:10              4.0
# 4         2  2026-01-01 00:27:13   2026-01-01 00:40:43              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           239           238
# 1           0.90         1.0                  N           163           162
# 2           1.40         1.0                  N            43           237
# 3           5.58         1.0                  N           142           209
# 4           2.16         1.0                  N            88           144
#
#    payment_type  ...  total_amount  congestion_surcharge  Airport_fee  \
# ...

# %%
# inspect memory used
# Out:
# Index                         132
# VendorID                 14899556
# tpep_pickup_datetime     29799112
# tpep_dropoff_datetime    29799112
# passenger_count          29799112
# trip_distance            29799112
# RatecodeID               29799112
# store_and_fwd_flag       32639411
# PULocationID             14899556
# DOLocationID             14899556
# payment_type             29799112
# fare_amount              29799112
# extra                    29799112
# mta_tax                  29799112
# tip_amount               29799112
# tolls_amount             29799112
# improvement_surcharge    29799112
# total_amount             29799112
# congestion_surcharge     29799112
# Airport_fee              29799112
# cbd_congestion_fee       29799112
# Trip_Duration            29799112
# Total_Trip_Charge        29799112
# Trip_Date                29799112
# Trip_Month               55873342
# Trip_Day                 56803857
# Trip_Year                14899556
# dtype: int64

# %%
# Total memory used
total_bytes = # TODO
print(f"{total_bytes / 1024**2:.2f} MB")   
print(f"{total_bytes / 1024**3:.2f} GB")
# Out:
# 735.38 MB
# 0.72 GB

# %%
# inspect DataFrame
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3724889 entries, 0 to 3724888
# Data columns (total 26 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     str
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
#  20  Trip_Duration          float64
# ...

# %%
# list existing columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee', 'Trip_Duration', 'Total_Trip_Charge', 'Trip_Date',
#        'Trip_Month', 'Trip_Day', 'Trip_Year'],
#       dtype='str')

# %%
# keep only specific columns 
# 'VendorID', 'passenger_count', 'trip_distance', 'store_and_fwd_flag', 'payment_type', 'Trip_Duration', 'Total_Trip_Charge', 'Trip_Date', 'Trip_Month', 'Trip_Year', 'Trip_Day'

# Reorder the columns, starting with Vendor ID, followed by all the different date/time columns example Date, Year, Month, and Day, then followed by the remaining columns 

cols = #TODO

df = df[cols]

# %%
# inspect the latest DataFrame 
df.head()
# Out:
#    VendorID  Trip_Date  Trip_Year Trip_Month  Trip_Day  passenger_count  \
# 0         2 2026-01-01       2026    January  Thursday              1.0
# 1         1 2026-01-01       2026    January  Thursday              0.0
# 2         1 2026-01-01       2026    January  Thursday              0.0
# 3         2 2026-01-01       2026    January  Thursday              4.0
# 4         2 2026-01-01       2026    January  Thursday              0.0
#
#    trip_distance store_and_fwd_flag  payment_type  Trip_Duration  \
# 0           0.97                  N             1            5.0
# 1           0.90                  N             2            5.0
# 2           1.40                  N             1            8.0
# 3           5.58                  N             1           42.0
# 4           2.16                  N             1           13.0
#
#    Total_Trip_Charge
# 0              15.86
# 1              16.15
# 2              21.45
# 3              54.81
# 4              22.35

# %% [markdown]
# Rename the columns:
# * `VendorID` to `Vendor_ID`
# * `passenger_count` to `No_of_Passengers`
# * `store_and_fwd_flag` to `SF_Flag`
# * `payment_type` to `Payment_Type`

# %%
# Rename the columns - see the output below
df = #TODO
df.head()
# Out:
#    Vendor_ID  Trip_Date  Trip_Year Trip_Month  Trip_Day  No_of_Passengers  \
# 0          2 2026-01-01       2026    January  Thursday               1.0
# 1          1 2026-01-01       2026    January  Thursday               0.0
# 2          1 2026-01-01       2026    January  Thursday               0.0
# 3          2 2026-01-01       2026    January  Thursday               4.0
# 4          2 2026-01-01       2026    January  Thursday               0.0
#
#    trip_distance SF_Flag  Payment_Type  Trip_Duration  Total_Trip_Charge
# 0           0.97       N             1            5.0              15.86
# 1           0.90       N             2            5.0              16.15
# 2           1.40       N             1            8.0              21.45
# 3           5.58       N             1           42.0              54.81
# 4           2.16       N             1           13.0              22.35

# %%
# Save as Parquet parition by Year, Month. You can call it 'Yellow Taxi Transformed'
# Hint: Use the OUT_DIR variable defined at the top of this notebook to save the file in the same directory as the original file.
# Hint: As an Example Your output should look like: 'outputs/Yellow_Taxi_Transformed/Trip_Year=2026/Trip_Month=January

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# * Inspect the Parquet folder, look at the partitions. Is there someting strange? Yes/No
# * If Yes. Find which rows are causing this and capture them
# * What do you think happened?

# %%
#TODO
# Out:
# Trip_Year=2025
# Trip_Year=2026
