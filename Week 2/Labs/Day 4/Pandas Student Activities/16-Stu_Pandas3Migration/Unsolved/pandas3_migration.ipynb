# %% [markdown]
# # Student Activity: What Changed in Pandas 3.0

# %%
# Import dependencies

# %% [markdown]
# ### 1. Default string dtype

# %%
# Build a small DataFrame with a text column and a numeric column
# Check df.dtypes. What dtype is the text column?

# %% [markdown]
# *Your observation here.*

# %% [markdown]
# ### 2. Chained assignment (the wrong way)

# %%
# Try: df[df["claim_type"] == "Auto"]["amount"] = 0
# Check whether df actually changed

# %% [markdown]
# ### 3. The correct way, with .loc

# %%
# Use df.loc[df["claim_type"] == "Auto", "amount"] = 0
# Confirm df changed this time

# %% [markdown]
# ### 4. Default datetime resolution

# %%
# Build a datetime index or Series from a list of date strings with pd.to_datetime
# Check .dtype. Is it datetime64[ns] or datetime64[us]?

# %% [markdown]
# ### Challenge: research one more pandas 3.0 change

# %% [markdown]
# *Your two or three sentences here, with a link to the release note you used.*
