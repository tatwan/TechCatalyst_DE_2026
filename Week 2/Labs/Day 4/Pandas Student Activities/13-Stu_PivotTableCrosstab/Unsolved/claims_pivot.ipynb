# %% [markdown]
# # Student Activity: Claims by Region and Type

# %%
# Import dependencies

# %% [markdown]
# ### 1. Read the CSV

# %%
# Read Resources/insurance_claims.csv into a DataFrame

# %% [markdown]
# ### 2. Pivot table: total claim_amount by region and claim_type

# %%
# pd.pivot_table with index="region", columns="claim_type", values="claim_amount", aggfunc="sum"

# %% [markdown]
# ### 3. Same pivot, but with the mean instead of the sum

# %%
# Same pivot_table call, aggfunc="mean"
# In a markdown cell below, compare a high-total/low-average combination to a low-total/high-average one

# %% [markdown]
# *Your comparison here.*

# %% [markdown]
# ### 4. Crosstab: count of claims by region and status

# %%
# pd.crosstab(df["region"], df["status"])

# %% [markdown]
# ### 5. Same crosstab, with row and column totals

# %%
# Same crosstab call, margins=True
# Confirm the grand total matches len(df)

# %% [markdown]
# ### Challenge: sum and count together

# %%
# pd.pivot_table with aggfunc=["sum", "count"] on claim_amount, by region and claim_type
