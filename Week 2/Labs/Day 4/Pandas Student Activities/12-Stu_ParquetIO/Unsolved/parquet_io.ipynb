# %% [markdown]
# # Student Activity: Parquet In, Parquet Out

# %%
# Import dependencies
import os

# %% [markdown]
# ### 1. Read the CSV and check dtypes

# %%
# Read Resources/insurance_claims.csv into a DataFrame
# Check df.dtypes. What dtype is claim_date?

# %% [markdown]
# ### 2. Convert claim_date to a real datetime column

# %%
# Use pd.to_datetime on the claim_date column

# %% [markdown]
# ### 3. Write the DataFrame to parquet

# %%
# Write to Resources/insurance_claims.parquet with df.to_parquet(..., index=False)

# %% [markdown]
# ### 4. Read the parquet file back and check dtypes

# %%
# Use pd.read_parquet and check .dtypes again

# %% [markdown]
# ### 5. Compare file sizes on disk

# %%
# Use os.path.getsize() on both files and compare

# %% [markdown]
# ### 6. Reflection
#
# Did claim_date come back as a datetime after the parquet round trip, or did you have to re-parse it like you did with the CSV? What does that tell you about why bronze/silver pipelines write parquet instead of CSV?
#
# *Your answer here.*

# %% [markdown]
# ### Challenge: partitioned parquet

# %%
# Filter to claim_amount > 5000, then write with partition_cols=["region"]
# Look at the folder structure this creates
