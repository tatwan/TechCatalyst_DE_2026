# %% [markdown]
# # Student Activity: Smoothing Out the Noise

# %%
# Import dependencies
# %matplotlib inline

# %% [markdown]
# ### 1. Read the CSV, parse the date, and set it as the index

# %%
# Read Resources/daily_claims_volume.csv
# Convert "date" to datetime and set it as the index

# %% [markdown]
# ### 2. Plot the raw daily claims_filed

# %%
# Plot claims_filed as a line chart

# %% [markdown]
# ### 3. 7-day rolling mean of claims_filed

# %%
# Create claims_7day_avg using .rolling(window=7).mean()

# %% [markdown]
# ### 4. Plot claims_filed and claims_7day_avg together

# %%
# Plot both columns on the same chart

# %% [markdown]
# ### 5. 7-day rolling sum of premium_collected

# %%
# Create premium_7day_total using .rolling(window=7).sum()

# %% [markdown]
# ### 6. Running (expanding) total of premium_collected

# %%
# Create premium_running_total using .expanding().sum()

# %% [markdown]
# ### 7. Reflection
#
# Why are the first 6 rows of claims_7day_avg and premium_7day_total NaN? What would you have to do differently if you needed a value for every row starting from day 1?
#
# *Your answer here.*

# %% [markdown]
# ### Challenge: compare a 3-day and a 7-day rolling mean

# %%
# Add a 3-day rolling mean and plot it with the 7-day rolling mean and the raw data
