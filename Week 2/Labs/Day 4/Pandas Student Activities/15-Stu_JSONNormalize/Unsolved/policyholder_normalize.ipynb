# %% [markdown]
# # Student Activity: Flattening Nested Policyholder Data

# %%
# Import dependencies
import json

# %% [markdown]
# ### 1. Load the raw JSON and inspect the first record

# %%
# Load Resources/policyholders.json with json.load
# Print the first record. Look at the nested "claims" list.

# %% [markdown]
# ### 2. json_normalize with no extra arguments

# %%
# pd.json_normalize(data)
# Look at the "claims" column. What type of object is in each cell?

# %% [markdown]
# ### 3. json_normalize with record_path and meta

# %%
# pd.json_normalize(data, record_path="claims", meta=["policyholder_id", "name", "state"])

# %% [markdown]
# ### 4. Reflection
#
# Which policyholders disappeared from the result in step 3, and why? What would a data engineer need to do differently if the business needs a row for every policyholder, including the ones with zero claims?
#
# *Your answer here.*

# %% [markdown]
# ### 5. Total claim amount per policyholder

# %%
# Group the flattened DataFrame from step 3 by policyholder_id and sum "amount"

# %% [markdown]
# ### Challenge: left join so zero-claim policyholders are not lost

# %%
# Build a policyholder-level DataFrame with pd.json_normalize(data) (no record_path)
# keeping only policyholder_id, name, state
# Merge it with your totals from step 5 using how="left", then fill missing totals with 0
